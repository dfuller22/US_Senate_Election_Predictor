# %% [markdown]
# # Capstone

# %% [markdown]
# ## Imports & links

# %%
import functions as dlf
import pandas as pd
import numpy as np
import requests
import regex
import pickle
from importlib import reload
from bs4 import BeautifulSoup

# %% [markdown]
# > [Link to Brookings](https://www.brookings.edu/multi-chapter-report/vital-statistics-on-congress/)
#
# > [Link to BallotPedia](https://ballotpedia.org/Legislative_Branch)
#
# > [Link to WikiPedia](https://en.wikipedia.org/wiki/List_of_United_States_Senate_elections)
#
# > [Link to Wiki-Category (U.S. Senator)](https://commons.wikimedia.org/wiki/Category:Senators_of_the_United_States)

# %% [markdown]
# Why after the 17th amendment?? [Link](https://en.wikipedia.org/wiki/Seventeenth_Amendment_to_the_United_States_Constitution)
#
# For 1920 forward, proceed like 1976. Prior to this, will need to use first table with general info.
#
# * **Clean up NaN value table from top of pages** -- Use index 2 to grab  nested table from `'infobox vevent'`.
# * **Take list of states of top tables** and map to dfs
# * Get demographic info wikidata
# * eda time series of state party (heatmap)
# * NLP on names, etc.
# * [link for slider viz](https://medium.com/@sjacks/the-journey-to-an-attractive-visualization-bac019506a49)

# %% [markdown]
# ## Building code

# %%
reload(dlf)
# Out:
# <module 'functions' from 'C:\\Users\\d_ful\\Documents\\GitHub\\Capstone_Project\\functions.py'>

# %%
# elect_yr_tables, elect_yr_tocs = wiki_senate_scraper()

# election_collection_raw = election_collector(elect_yr_tables, elect_yr_tocs)

# %%
## This works for all years up until 2018 (doesnt have these tables)

# yr_sum_tables = dlf.yr_summary_collector(election_collection_raw)
# yr_sum_dict = dlf.yr_sum_formatter(yr_sum_tables)
# name_lookup_df = dlf.master_tabler(yr_sum_dict)

# %%
# yr_st_elects = dlf.st_election_collector(election_collection_raw)
# print(('---'*10)+'Step 1 Complete!'+('---'*10))
# print('yr_st_elects length:', len(yr_st_elects))

# yr_st_dict = dlf.st_election_cleaner(yr_st_elects)
# print(('---'*10)+'Step 2 Complete!'+('---'*10))

# yr_st_dict_joined = dlf.st_election_aggregator(yr_st_dict)
# print(('---'*10)+'Step 3 Complete!'+('---'*10))

# yr_st_dict_mapped = dlf.st_election_state_mapper(yr_st_dict_joined, name_lookup_df)
# print(('---'*10)+'Step 4 Complete!'+('---'*10))

# yr_st_mapped_full = dlf.yr_st_mapped_NA_handler(yr_st_dict_mapped)
# print(('---'*10)+'Step 5 Complete!'+('---'*10))
# Out:
# 4 NA operations completed.
# ------------------------------Step 5 Complete!------------------------------

# %%
# sen_leader_tables = dlf.sen_leader_collector(election_collection_raw)

# sen_leader_dict = dlf.sen_leader_cleaner(sen_leader_tables)

# test = dlf.table_checker(dict_=sen_leader_dict)
# print(type(test))
# test

# %%
# ldr_master_df = dlf.master_leader_tabler(sen_leader_dict)
# ldr_master_df

# ldr_master_df_model = dlf.master_leader_cleaner(ldr_master_df, rd_stand=True, fillna_stand=True)
# ldr_master_df_model = dlf.regex_subber_bycol(ldr_master_df_model, 'Leader', 
#                                          [r'\(([^\)]+)\)', r'\[([^\)]+)\]'],
#                                          multi_patt=True)
# ldr_master_df_model

# %% [markdown]
# ## Pickless....

# %% [markdown]
# ### Writing..

# %%
# with open('election_collection_raw.pickle', 'wb') as f:
#     pickle.dump(election_collection_raw, f)
#     f.close()

# %%
# with open('yr_sum_tables.pickle', 'wb') as f:
#     pickle.dump(yr_sum_tables, f)
#     f.close()

# %%
# with open('yr_sum_dict.pickle', 'wb') as f:
#     pickle.dump(yr_sum_dict, f)
#     f.close()

# %%
# with open('name_lookup_df.pickle', 'wb') as f:
#     pickle.dump(name_lookup_df, f)
#     f.close()

# %%
# with open('yr_st_elects.pickle', 'wb') as f:
#     pickle.dump(yr_st_elects, f)
#     f.close()

# %%
# with open('yr_st_dict.pickle', 'wb') as f:
#     pickle.dump(yr_st_dict, f)
#     f.close()

# %%
# with open('yr_st_dict_joined.pickle', 'wb') as f:
#     pickle.dump(yr_st_dict_joined, f)
#     f.close()

# %%
# with open('yr_st_dict_mapped.pickle', 'wb') as f:
#     pickle.dump(yr_st_dict_mapped, f)
#     f.close()

# %%
# with open('sen_leader_tables.pickle', 'wb') as f:
#     pickle.dump(sen_leader_tables, f)
#     f.close()

# %%
# with open('sen_leader_dict.pickle', 'wb') as f:
#     pickle.dump(sen_leader_dict, f)
#     f.close()

# %%
# with open('ldr_master_df.pickle', 'wb') as f:
#     pickle.dump(ldr_master_df, f)
#     f.close()

# %%
# with open('ldr_master_df_model.pickle', 'wb') as f:
#     pickle.dump(ldr_master_df_model, f)
#     f.close()

# %%
# with open('yr_st_mapped_full.pickle', 'wb') as f:
#     pickle.dump(yr_st_mapped_full, f)
#     f.close()

# %% [markdown]
# ### Reading..

# %%
# with open('election_collection_raw.pickle', 'rb') as f:
#     election_collection_raw = pickle.load(f)
#     f.close()

# %%
# with open('yr_sum_tables.pickle', 'rb') as f:
#     yr_sum_tables = pickle.load(f)
#     f.close()

# %%
# with open('yr_sum_dict.pickle', 'rb') as f:
#     yr_sum_dict = pickle.load(f)
#     f.close()

# %%
with open('name_lookup_df.pickle', 'rb') as f:
    name_lookup_df = pickle.load(f)
    f.close()

# %%
# with open('yr_st_elects.pickle', 'rb') as f:
#     yr_st_elects = pickle.load(f)
#     f.close()

# %%
# with open('yr_st_dict.pickle', 'rb') as f:
#     yr_st_dict = pickle.load(f)
#     f.close()

# %%
# with open('yr_st_dict_joined.pickle', 'rb') as f:
#     yr_st_dict_joined = pickle.load(f)
#     f.close()

# %%
with open('yr_st_dict_mapped.pickle', 'rb') as f:
    yr_st_dict_mapped = pickle.load(f)
    f.close()

# %%
with open('yr_st_mapped_full.pickle', 'rb') as f:
    yr_st_mapped_full = pickle.load(f)
    f.close()

# %%
# with open('sen_leader_tables.pickle', 'rb') as f:
#     sen_leader_tables = pickle.load(f)
#     f.close()

# %%
with open('sen_leader_dict.pickle', 'rb') as f:
    sen_leader_dict = pickle.load(f)
    f.close()

# %%
# with open('ldr_master_df.pickle', 'rb') as f:
#     ldr_master_df = pickle.load(f)
#     f.close()

# %%
with open('ldr_master_df_model.pickle', 'rb') as f:
    ldr_master_df_model = pickle.load(f)
    f.close()

# %%
## Must do this befor running code for state elections. Error in code
# do_not_use = election_collection_raw['2018'][2].pop(0)

# %% [markdown]
# ## Workshop

# %% [markdown]
# Need to go through and format these tables across all elections. then can finally take info from each of the sections to create final year dataframes

# %%
# reload(dlf)

# %%
## Display year's summary with incumbent and results
# test2 = dlf.table_checker(dict_=yr_sum_dict)
# print(type(test2))
# for table in test2:
#     display(table.head(10))

# %%
## Display year's state elections
# test3 = dlf.table_checker(dict_=yr_st_dict_mapped)
# print(type(test3))
# test3

# %%
# display(name_lookup_df.head(15))

# %%
display(ldr_master_df_model.head(15))
ldr_master_df_model.info()
# Out:
#                 Leader   Leaders_seat     Leader_since         Party Seats_up  \
# 0      Mitch McConnell       Kentucky  January 3, 2007    Republican        9
# 1        Chuck Schumer       New York  January 3, 2017    Democratic       24
# 2            3rd Party      3rd Party  January 3, 2017   Independent        2
# 3         John W. Kern        Indiana    March 4, 1913    Democratic       16
# 4   Jacob H. Gallinger  New Hampshire    March 4, 1913    Republican       18
# 5            3rd Party      3rd Party    March 4, 1913   Progressive        0
# 6         John W. Kern        Indiana    March 4, 1913    Democratic       17
# 7   Jacob H. Gallinger  New Hampshire    March 4, 1913    Republican       15
# 8    Henry Cabot Lodge  Massachusetts    March 4, 1919    Republican       17
# 9      Oscar Underwood        Alabama   April 27, 1920    Democratic       24
# 10   Henry Cabot Lodge  Massachusetts    March 4, 1919    Republican       15
# 11     Oscar Underwood        Alabama   April 27, 1920    Democratic       17
# 12   Henry Cabot Lodge  Massachusetts    March 4, 1919    Republican       17
# 13     Oscar Underwood        Alabama   April 27, 1920    Democratic       15
# 14           3rd Party      3rd Party   April 27, 1920  Farmer–Labor        0
#
#    Seats_before  Year
# 0            51  2018
# 1            47  2018
# 2             2  2018
# 3            50  1914
# 4            44  1914
# 5             1  1914
# 6            56  1916
# 7            40  1916
# 8            43  1918
# 9            53  1918
# 10           49  1920
# 11           47  1920
# 12           60  1922
# 13           36  1922
# 14            0  1922
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
# Leader          148 non-null object
# Leaders_seat    148 non-null object
# Leader_since    148 non-null object
# Party           148 non-null object
# Seats_up        148 non-null object
# Seats_before    148 non-null object
# Year            148 non-null object
# dtypes: object(7)
# memory usage: 8.2+ KB

# %%
# reload(dlf)

# %%
test = name_lookup_df[name_lookup_df['Year']=='1986'].copy()
test
# Out:
#                      State_id        Incumbent       Party  Year  \
# 1307                  Alabama  Jeremiah Denton  Republican  1986
# 1308                   Alaska  Frank Murkowski  Republican  1986
# 1309                  Arizona  Barry Goldwater  Republican  1986
# 1310                 Arkansas     Dale Bumpers  Democratic  1986
# 1311               California    Alan Cranston  Democratic  1986
# 1312                 Colorado        Gary Hart  Democratic  1986
# 1313              Connecticut       Chris Dodd  Democratic  1986
# 1314                  Florida    Paula Hawkins  Republican  1986
# 1315                  Georgia   Mack Mattingly  Republican  1986
# 1316                   Hawaii    Daniel Inouye  Democratic  1986
# 1317                    Idaho      Steve Symms  Republican  1986
# 1318                 Illinois    Alan J. Dixon  Democratic  1986
# 1319                  Indiana       Dan Quayle  Republican  1986
# 1320                     Iowa   Chuck Grassley  Republican  1986
# 1321                   Kansas         Bob Dole  Republican  1986
# 1322                 Kentucky     Wendell Ford  Democratic  1986
# 1323                Louisiana  Russell B. Long  Democratic  1986
# 1324                 Maryland  Charles Mathias  Republican  1986
# 13          1        Arkansas        Dale Bumpers  1986                0
# 14          0        Arkansas      Asa Hutchinson  1986                0
# 15          0        Arkansas        Ralph Forbes  1986                0
# 16          1      California       Alan Cranston  1986                0
# 17          0      California           Ed Zschau  1986                0
# 18          0      California     Edward B Vallen  1986                0
# 19          0      California      Breck McKinley  1986                0
# 20          0      California         Paul Kangas  1986                0
# 21          0        Colorado           Tim Wirth  1986                0
# 22          0        Colorado          Ken Kramer  1986                0
# 23          0        Colorado   Henry John Olshaw  1986                0
# 24          1        Colorado         Christ Dodd  1986                0
# 25          0        Colorado          Roger Eddy  1986                0
# 26          0        Colorado    Edward McCallum,  1986                0
# 27          0         Florida          Bob Graham  1986                0
# 28          1         Florida       Paula Hawkins  1986                0
# 29          0         Georgia        Wyche Fowler  1986                0
# ..        ...             ...                 ...   ...              ...
# 72          0            Ohio        Tom Kindness  1986                0
# 73          0            Ohio     Kathleen Button  1986                0
# 74          0            Ohio      William Harris  1986                0
# 75          1        Oklahoma         Don Nickles  1986                0
# 76          0        Oklahoma         James Jones  1986                0
# 77          1          Oregon        Bob Packwood  1986                0
# 78          0          Oregon         Rick Bauman  1986                0
# 79          0          Oregon            Write-in  1986                0
# 80          1    Pennsylvania       Arlen Specter  1986                0
# 81          0    Pennsylvania        Robert Edgar  1986                0
# 82          0    Pennsylvania         Lance Haver  1986                0
# 83          1  South_Carolina      Fritz Hollings  1986                0
# 84          0  South_Carolina      Henry McMaster  1986                0
# 85          0  South_Carolina  Steven Vandervelde  1986                0
# 86          0  South_Carolina        Ray Hillyard  1986                0
# 87          0  South_Carolina           Write-Ins  1986                0
# 88          0    South_Dakota         Tom Daschle  1986                0
# 89          1    South_Dakota        James Abdnor  1986                0
# 90          1            Utah           Jake Garn  1986                0
# 91          0            Utah        Craig Oliver  1986                0
# 92          0            Utah         Hugh Butler  1986                0
# 93          0            Utah           Mary Zins  1986                0
# 94          0            Utah           Write-Ins  1986                0
# 95          1         Vermont       Patrick Leahy  1986                0
# 96          0         Vermont    Richard Snelling  1986                0
# 97          0      Washington         Brock Adams  1986                0
# 98          1      Washington        Slade Gorton  1986                0
# 99          0      Washington           Jill Fein  1986                0
# 100         1       Wisconsin          Bob Kasten  1986                0
# 101         0       Wisconsin           Ed Garvey  1986                0
#
# [102 rows x 9 columns]

# %%
for col, item in zip(test2.columns, test2.iloc[0]):
    print(f'{col}:')
    print(item, type(item))
    print('')
# Out:
# Party:
# Democratic <class 'str'>
#
# Candidate:
# James Allen <class 'str'>
#
# %:
# 69.71% <class 'str'>
#
# Turnout:
# 916300 <class 'str'>
#
# Incumb_Y:
# 0 <class 'numpy.int64'>
#
# State:
# Alabama <class 'str'>
#
# Term_in_office:
# 0 <class 'numpy.int64'>

# %%
## REFORMATTING % AS A FLOAT    
for i, p in zip(test2.index, test2['%']):
    if isinstance(p, str):
        if '%' in p:
            test2.at[i, '%'] = np.float(p[:-1])

## REMOVING () & [] FROM THE NAMES
test2 = dlf.regex_subber_bycol(test2, 'Candidate', [r'\(([^\)]+)\)', r'\[([^\)]+)\]'], multi_patt=True)

## MAKING SURE THE NAMES MATCH

# test2['Cln_name'] = test2['Candidate'].map(lambda x: regex.sub(r'([A-z]{1,2}\.)\s?', '', x).strip())
# test['Cln_name'] = test['Incumbent'].map(lambda x: regex.sub(r'([A-z]{1,2}\.)\s?', '', x).strip())

for n_idx, name in zip(test2.index, test2['Cln_name']):
    for i_idx, incmb in zip(test.index, test['Cln_name']):
        if incmb == name:
            test2.at[n_idx, 'Terms_in_office'] = test['Terms_in_office'][i_idx]
            
            if test2['Incumb_Y'][n_idx] != 1:
                test2.at[n_idx, 'Incumb_Y'] = 1  
        
            if test2['Party'][n_idx] != test['Party'][i_idx]:
                test2.at[n_idx, 'Party'] = test['Party'][i_idx]         
                
test2
# Out:
#                     Party                Candidate      %  Turnout  Incumb_Y  \
# 0              Democratic           Richard Shelby  50.28  1211897         0
# 1              Republican         Jeremiah Denton   49.72  1211897         1
# 2              Republican         Frank Murkowski   63.11   145310         1
# 3              Democratic               Glenn Olds  25.46   145310         0
# 4              Democratic              Bill Barnes   3.35   145310         0
# 5             Libertarian              Chuck House   2.94   145310         0
# 6              Democratic          Dave J. Carlson    2.9   145310         0
# 7              Democratic        Michael J. Bruner   1.24   145310         0
# 8              Democratic             Karl Francis      1   145310         0
# 9              Republican         Frank Murkowski   54.02   180801         1
# 10             Democratic               Glenn Olds   44.1   180801         0
# 11             Republican             John McCain   60.47   862921         1
# 12             Democratic          Richard Kimball  39.51   862921         0
# 13             Democratic            Dale Bumpers    62.3   695487         1
# 14             Republican           Asa Hutchinson   37.7   695487         0
# 15            Independent             Ralph Forbes    0.1   695487         0
# 16             Democratic           Alan Cranston    49.3  7398522         1
# 17             Republican                Ed Zschau   47.9  7398522         0
# 18   American Independent          Edward B Vallen    1.5  7398522         0
# 19            Libertarian           Breck McKinley    0.9  7398522         0
# 20      Peace and Freedom              Paul Kangas    0.5  7398522         0
# 21             Democratic                Tim Wirth  49.91  1060765         0
# 22             Republican               Ken Kramer  48.36  1060765         0
# 23   Independent American        Henry John Olshaw   0.18  1060765         0
# 24             Democratic             Christ Dodd    64.8   976933         1
# 25             Republican               Roger Eddy   34.9   976933         0
# 26            Independent  Edward J. McCallum, Jr.    0.4   976933         0
# 27             Democratic               Bob Graham  54.74  3429996         0
# 28             Republican           Paula Hawkins   45.26  3429996         1
# 29             Democratic             Wyche Fowler  50.91  1225008         0
# ..                    ...                      ...    ...      ...       ...
# 72             Republican             Tom Kindness   37.6  3121189         0
# 73            Independent       Kathleen M. Button      0  3121189         0
# 74            Independent        William M. Harris      0  3121189         0
# 75             Republican             Don Nickles    55.2   893666         1
# 76             Democratic           James R. Jones   44.8   893666         0
# 77             Republican            Bob Packwood   62.95  1042555         1
# 78             Democratic              Rick Bauman  36.04  1042555         0
# 79       Independent (US)                 Write-in   1.01  1042555         0
# 80             Republican           Arlen Specter    56.4  3378226         1
# 81             Democratic          Robert W. Edgar   42.9  3378226         0
# 82            Independent           Lance S. Haver    0.7  3378226         0
# 83             Democratic          Fritz Hollings    63.1   738062         1
# 84             Republican           Henry McMaster   35.6   738062         0
# 90             Utah           Jake Garn  1986                2
# 91             Utah        Craig Oliver  1986                0
# 92             Utah         Hugh Butler  1986                0
# 93             Utah           Mary Zins  1986                0
# 94             Utah           Write-Ins  1986                0
# 95          Vermont       Patrick Leahy  1986                2
# 96          Vermont    Richard Snelling  1986                0
# 97       Washington         Brock Adams  1986                0
# 98       Washington        Slade Gorton  1986                1
# 99       Washington           Jill Fein  1986                0
# 100       Wisconsin          Bob Kasten  1986                1
# 101       Wisconsin           Ed Garvey  1986                0
#
# [102 rows x 9 columns]

# %%
test2['Party'].value_counts()
# Out:
# Republican              36
# Democratic              35
# Libertarian             11
# Independent             10
# Socialist Workers        7
# Communist                3
# Workers World            2
# People Over Politics     1
# Conservative             1
# No Party                 1
# Liberty Union            1
# American Independent     1
# National Democrat        1
# No party                 1
# Statesman Party          1
# Consumer                 1
# Constitution             1
# American                 1
# Peace and Freedom        1
# Concerned Citizens       1
# Name: Party, dtype: int64

# %%
## Starter code for matchup of terms in office. need to clean each df first 

# for idx, name in zip(test2.index, test2['Candidate']):
#     for incumb in test['Incumbent']:
#         if name == incumb:
#             print('!')
# Out:
# !

# %% [markdown]
# combine yearly tables, add state/year column

# %% [markdown]
# 8.9 Need to try and merge `yr_st_dict_mapped`, `ldr_master_df` and use parts of `name_lookup_df`
#
# 8.12 Need to implement NA strats below then begin merging
#
# **8.15 Look for more ways to engineer feats; Implement cleaning code into function. Group parties once all years are together. Make code to put in party of senate leader, majority party, and if third party in senate at all.**

# %%
for year in yr_st_mapped_full:
    table = yr_st_mapped_full[year]
    print(f'{year}')
    print(table['State'].value_counts(ascending=True))
# Out:
# 1920
# South_Carolina    2
# Arizona           2
# Virginia          2
# Arkansas          2
# Idaho             2
# Ohio              3
# Utah              3
# Vermont           3
# Kansas            3
# Oklahoma          3
# North_Carolina    4
# Iowa              4
# Nevada            4
# South_Dakota      5
# Indiana           5
# Missouri          5
# Oregon            5
# Florida           6
# Connecticut       6
# Alabama           6
# Pennsylvania      7
# Illinois          7
# California        8
# Kentucky          8
# New_Hampshire     9
# Washington        9
# Name: State, dtype: int64
# 1922
# New_Mexico        2
# Texas             2
# Arizona           2
# Maine             2
# North_Dakota      2
# Nevada            2
# Iowa              2
# Tennessee         2
# New_Jersey        2
# Ohio              3
# Michigan          3
# Nebraska          3
# Mississippi       3
# Montana           3
# Wyoming           3
# Utah              3
# Minnesota         3
# West_Virginia     3
# Florida           4
# Wisconsin         4
# Maryland          4
# California        4
# Connecticut       4
# Rhode_Island      4
# Missouri          4
# Vermont           5
# Delaware          5
# Washington        5
# New_York          5
# Massachusetts     7
# Pennsylvania     18
# Name: State, dtype: int64
# 1924
# New_Mexico         2
# Alabama            2
# Maine              2
# Texas              2
# Nebraska           2
# Arkansas           2
# North_Carolina     2
# Delaware           2
# Connecticut        3
# Oklahoma           3
# Idaho              3
# West_Virginia      3
# Virginia           3
# Oregon             4
# Massachusetts      4
# Wyoming            4
# Iowa               5
# Minnesota          5
# Montana            5
# Kansas             6
# Illinois           7
# New_Hampshire      9
# Rhode_Island       9
# Colorado           9
# South_Dakota      10
test = yr_st_mapped_full['1992'].copy()
# test['State'].fillna(method='ffill', inplace=True)
# display(test.info())
test.tail(20)
# Out:
#                     Party                          Candidate       %  Turnout  \
# 108              No party                          Write-Ins    0.1%  1180438
# 109            Democratic            Tom Daschle (Incumbent)  64.90%   334495
# 110            Republican                      Charlene Haar  32.51%   334495
# 111            Republican                        Bob Bennett  55.38%   758479
# 112            Democratic                        Wayne Owens  39.72%   758479
# 113              Populist                       Anita Morrow   2.31%   758479
# 114           Libertarian                       Maury Modine   1.89%   758479
# 115     Socialist Workers                    Patricia Grogan    0.7%   758479
# 116            Democratic          Patrick Leahy (Incumbent)  54.16%   285739
# 117            Republican                        Jim Douglas  43.35%   285739
# 118         Liberty Union                         Jerry Levy   1.79%   285739
# 119            Democratic                       Patty Murray   54.0%  2218802
# 120            Republican                       Rod Chandler   46.0%  2218802
# 121            Democratic                   Russell Feingold   52.6%  2454665
# 122            Republican  Robert W. Kasten, Jr. (Incumbent)   46.0%  2454665
# 123           Independent                    Patrick Johnson    0.7%  2454665
# 124           Libertarian                    William Bittner    0.4%  2454665
# 125           Independent              Mervin A. Hanson, Sr.    0.1%  2454665
# 126            Grassroots                  Robert L. Kundert    0.1%  2454665
# 127  Independent Populist                    Joseph Selliken    0.1%  2454665
#
#      Incumb_Y           State                    Cln_name
# 108         0  South_Carolina                   Write-Ins
# 109         1    South_Dakota     Tom Daschle (Incumbent)
# 110         0    South_Dakota               Charlene Haar
# 111         0            Utah                 Bob Bennett
# 112         0            Utah                 Wayne Owens
# 113         0            Utah                Anita Morrow
# 114         0            Utah                Maury Modine
# 115         0            Utah             Patricia Grogan
# 116         1         Vermont   Patrick Leahy (Incumbent)
# 117         0         Vermont                 Jim Douglas
# 118         0         Vermont                  Jerry Levy
# 119         0      Washington                Patty Murray
# 120         0      Washington                Rod Chandler
# 121         0       Wisconsin            Russell Feingold
# 122         1       Wisconsin  Robert Kasten, (Incumbent)
# 123         0       Wisconsin             Patrick Johnson
# 124         0       Wisconsin             William Bittner
# 125         0       Wisconsin              Mervin Hanson,
# 126         0       Wisconsin              Robert Kundert
# 127         0       Wisconsin             Joseph Selliken

# %%
test1 = dlf.table_checker(dict_=yr_st_mapped_full)
# display(test1.head(10))#[25:35])
# # print(test1[0]['Total votes'])
# # display(test1[test1['State'].isna()])
# # display(type(test1['%'][25]))
test1.info()
# Out:
# Key to pull:1992
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 6 columns):
# Party        134 non-null object
# Candidate    134 non-null object
# %            134 non-null object
# Turnout      134 non-null object
# Incumb_Y     134 non-null int64
# State        38 non-null object
# dtypes: int64(1), object(5)
# memory usage: 6.4+ KB

# %% [markdown]
# #### Removal plan for 'Turnout'

# %% [markdown]
# **1928:** MA: 36-39 [1,524,914], PA: 91-97 [3,026,864]
#
# **1930:** MA: 42-46 [1,207,011]
#
# **1932:** AR: 6-8 [33,980], CO: 16-18 [425,634], NC: 87-88 [706,440]
#
# **1934:** TN: 98-100 [308,274]
#
# **1936:** MA: 41-50 [1,803,674]
#
# **1942:** ID: 13-14 [142,342], RI: 73-74 [238,487]
#
# **1952:** MI: 34-39 [2,821,133]
#
# **1958:** NC: 59-60 [616,469]
#
# **1974:** IA: 45-47 [853,521]

# %% [markdown]
# **1976**: UT: 102-103 [514,169]
#
# **1980**: OK: 83-87 [1,098,294]
#
# **1986**: KY: 45-46 [677,105]
#
# **1994**: HI: 20-22 [356,902]
#
# **1998**: Just drop the other rows
#
# **2000**: CT: 12-15 [1,311,261], MS: 61-65 [944,144], NJ: 80-90 [3,015,662], TN: 106-112 [1,928,613], TX: 113-116 [6,267,964], WV: 127-129 [603,477], WI: 130-135 [2,540,083]
#
# **2002**: AR: 7-8 [808,256], NH: 64-66 [444,542], NJ: 67-72 [2,112,604]
#
# **2004**: AR: 10-12 [1,039,439], CT: 24-27 [1,424,726]
#
# **2006**: Just drop the other rows
#
# **2012**: ME: 19-21 [693,787], MN: 34-36 [2,839,572]

# %% [markdown]
# * **1928**: MA doesn't report here. PA maybe under 'Totals'
# * **1930**: MA doesn't report here.
# * **1932**: AR/CO/NC doesn't report here.
# * **1934**: TN doesn't report here.
# * **1936**: MA maybe under 'total'
# * **1942**: ID/RI doesn't report here.
# * **1952**: MI doesn't report here.
# * **1958**: NC doesn't report here.
# * **1974**: IA doesn't report here.

# %% [markdown]
# * **1976**: UT doesn't report here.
# * **1980**: OK doesn't report here.
# * **1986**: KY doesn't report here.
# * **1994**: Idx [3,4] need to be dropped. HI doesn't report here.
# * **1998**: Idx [18-22] need to be dropped.
# * **2000**: Idx [2-4] need to be dropped. CT/MS/NJ/TN/TX/WV/WI doesn't report here.
# * **2002**: AR/NH/NJ doesn't report here.
# * **2004**: AR/CT doesn't report here.
# * **2006**: Idx [3-6] & [103-107] need to be dropped.
# * **2012**: ME/MN doesn't report here.

# %% [markdown]
# #### Removal plan for 'Candidate'

# %% [markdown]
# Only in 1932:
# * **one** of these idx [30, 31, 32] needs to be changed to: 	Duncan U. Fletcher (Incumbent), Democratic, 1, Florida, 100%
# * The rest need to be dropped.

# %% [markdown]
# #### %

# %% [markdown]
# * **1932**: Taken care of in 'Candidate'
# * **1956**: Idx [68] needs to be changed to: 100%. Idx [69, 70] need to be dropped.
# * **2012**: Idx [25, 26, 52, 53, 54] needs to be (53.74, 46.19, 58.87, 39.37, 0.50) resp.
# * **2014**: Idx [91, 92, 93, 94] needs to be (48.82, 47.26, 3.74, 0.18) resp.

# %% [markdown]
# #### State

# %% [markdown]
# Just forward fill states after all other NAs have been filled or dropped.

# %% [markdown]
# **1924**: Idx [0-1] = 'Alabama'
#
# **1950**: Idx [0-1] = 'Alabama'
#
# **1960**: Idx [0-1] = 'Alabama'
#
# **1962**: Idx [0-1] = 'Alabama'
#
# **1966**: Idx [0-3] = 'Alabama'
#
# **1992**: Idx [0-3] = 'Alabama'; Idx [4-9] DROP

# %% [markdown]
# #### Next..

# %%
# test = dlf.table_checker(dict_=yr_st_dict_joined)
# display(test.head(10))
# # print(test[0]['Total votes'])
# test.info()

# %%
# test1['State'].fillna(method='ffill', inplace=True)
# display(test1.head(15))
# display(test1.tail(15))
# test1.info()

# %% [markdown]
# To help with repeat due to edge cases, remove first instance of name from each table.
