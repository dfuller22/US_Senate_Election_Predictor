# %% [markdown]
# # Capstone

# %% [markdown]
# ## Imports & links

# %%
import functions as dlf
import pandas as pd
import numpy as np
import requests
import re
import pickle
from importlib import reload
from bs4 import BeautifulSoup

# %% [markdown]
# > [Link to Brookings](https://www.brookings.edu/multi-chapter-report/vital-statistics-on-congress/)
#
# > [Link to BallotPedia](https://ballotpedia.org/Legislative_Branch)
#
# > [Link to WikiPedia](https://en.wikipedia.org/wiki/List_of_United_States_Senate_elections)
#
# > [Link to Wiki-Category (U.S. Senator)](https://commons.wikimedia.org/wiki/Category:Senators_of_the_United_States)

# %% [markdown]
# Why after the 17th amendment?? [Link](https://en.wikipedia.org/wiki/Seventeenth_Amendment_to_the_United_States_Constitution)
#
# For 1920 forward, proceed like 1976. Prior to this, will need to use first table with general info.
#
# * **Clean up NaN value table from top of pages** -- Use index 2 to grab  nested table from `'infobox vevent'`.
# * **Take list of states of top tables** and map to dfs
# * Get demographic info wikidata
# * eda time series of state party (heatmap)
# * NLP on names, etc.
# * [link for slider viz](https://medium.com/@sjacks/the-journey-to-an-attractive-visualization-bac019506a49)

# %% [markdown]
# ## Building code

# %%
reload(dlf)
# Out:
# <module 'functions' from 'C:\\Users\\d_ful\\Documents\\GitHub\\Capstone_Project\\functions.py'>

# %%
# elect_yr_tables, elect_yr_tocs = wiki_senate_scraper()

# election_collection_raw = election_collector(elect_yr_tables, elect_yr_tocs)

# %%
## This works for all years up until 2018 (doesnt have these tables)

# yr_sum_tables = dlf.yr_summary_collector(election_collection_raw)
# yr_sum_dict = dlf.yr_sum_formatter(yr_sum_tables)
# name_lookup_df = dlf.master_tabler(yr_sum_dict)

# %%
# yr_st_elects = dlf.st_election_collector(election_collection_raw)
# print(('---'*10)+'Step 1 Complete!'+('---'*10))
# print('yr_st_elects length:', len(yr_st_elects))

# yr_st_dict = dlf.st_election_cleaner(yr_st_elects)
# print(('---'*10)+'Step 2 Complete!'+('---'*10))

# yr_st_dict_joined = dlf.st_election_aggregator(yr_st_dict)
# print(('---'*10)+'Step 3 Complete!'+('---'*10))

# yr_st_dict_mapped = dlf.st_election_state_mapper(yr_st_dict_joined, name_lookup_df)
# print(('---'*10)+'Step 4 Complete!'+('---'*10))

# %%
# yr_st_dict_joined = dlf.st_election_aggregator(yr_st_dict)
# print(('---'*10)+'Step 1 Complete!'+('---'*10))
# yr_st_dict_mapped = dlf.st_election_state_mapper(yr_st_dict_joined, name_lookup_df)

# %%
# sen_leader_tables = dlf.sen_leader_collector(election_collection_raw)

# sen_leader_dict = dlf.sen_leader_cleaner(sen_leader_tables)

# test = dlf.table_checker(dict_=sen_leader_dict)
# print(type(test))
# test

# %%
# ldr_master_df = dlf.master_leader_tabler(sen_leader_dict)
# ldr_master_df
# Out:
# Update! New col len 9.
# Update! New year 1914.
# Update! New col len 10.
# Update! New year 1918.
# Update! New col len 12.
# Update! New year 1940.
# Update! New col len 13.
# Update! New year 1942.
# Update! New col len 14.
# Update! New year 2018.
# C:\Users\d_ful\Documents\GitHub\Capstone_Project\functions.py:547: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   ldr_master_df = pd.concat(holder2, ignore_index=True)

# %% [markdown]
# ## Pickless....

# %% [markdown]
# ### Writing..

# %%
# with open('election_collection_raw.pickle', 'wb') as f:
#     pickle.dump(election_collection_raw, f)
#     f.close()

# %%
# with open('yr_sum_tables.pickle', 'wb') as f:
#     pickle.dump(yr_sum_tables, f)
#     f.close()

# %%
# with open('yr_sum_dict.pickle', 'wb') as f:
#     pickle.dump(yr_sum_dict, f)
#     f.close()

# %%
# with open('name_lookup_df.pickle', 'wb') as f:
#     pickle.dump(name_lookup_df, f)
#     f.close()

# %%
# with open('yr_st_elects.pickle', 'wb') as f:
#     pickle.dump(yr_st_elects, f)
#     f.close()

# %%
# with open('yr_st_dict.pickle', 'wb') as f:
#     pickle.dump(yr_st_dict, f)
#     f.close()

# %%
# with open('yr_st_dict_joined.pickle', 'wb') as f:
#     pickle.dump(yr_st_dict_joined, f)
#     f.close()

# %%
# with open('yr_st_dict_mapped.pickle', 'wb') as f:
#     pickle.dump(yr_st_dict_mapped, f)
#     f.close()

# %%
# with open('sen_leader_tables.pickle', 'wb') as f:
#     pickle.dump(sen_leader_tables, f)
#     f.close()

# %%
# with open('sen_leader_dict.pickle', 'wb') as f:
#     pickle.dump(sen_leader_dict, f)
#     f.close()

# %%
# with open('ldr_master_df.pickle', 'wb') as f:
#     pickle.dump(ldr_master_df, f)
#     f.close()

# %% [markdown]
# ### Reading..

# %%
with open('election_collection_raw.pickle', 'rb') as f:
    election_collection_raw = pickle.load(f)
    f.close()

# %%
with open('yr_sum_tables.pickle', 'rb') as f:
    yr_sum_tables = pickle.load(f)
    f.close()

# %%
with open('yr_sum_dict.pickle', 'rb') as f:
    yr_sum_dict = pickle.load(f)
    f.close()

# %%
with open('name_lookup_df.pickle', 'rb') as f:
    name_lookup_df = pickle.load(f)
    f.close()

# %%
with open('yr_st_elects.pickle', 'rb') as f:
    yr_st_elects = pickle.load(f)
    f.close()

# %%
with open('yr_st_dict.pickle', 'rb') as f:
    yr_st_dict = pickle.load(f)
    f.close()

# %%
with open('yr_st_dict_joined.pickle', 'rb') as f:
    yr_st_dict_joined = pickle.load(f)
    f.close()

# %%
with open('yr_st_dict_mapped.pickle', 'rb') as f:
    yr_st_dict_mapped = pickle.load(f)
    f.close()

# %%
with open('sen_leader_tables.pickle', 'rb') as f:
    sen_leader_tables = pickle.load(f)
    f.close()

# %%
with open('sen_leader_dict.pickle', 'rb') as f:
    sen_leader_dict = pickle.load(f)
    f.close()

# %%
with open('ldr_master_df.pickle', 'rb') as f:
    ldr_master_df = pickle.load(f)
    f.close()

# %%
## Must do this befor running code for state elections. Error in code
do_not_use = election_collection_raw['2018'][2].pop(0)

# %% [markdown]
# ## Workshop

# %% [markdown]
# Need to go through and format these tables across all elections. then can finally take info from each of the sections to create final year dataframes

# %%
#reload(dlf)

# %%
for i in res_df2['d']:
    print(type(i))
    
## Numbers in tables are strings
## Regex for [a] or similar
##
# Out:
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
test2 = dlf.table_checker(dict_=yr_sum_dict)
print(type(test2))
for table in test2:
    display(table.head(10))
# Out:
# Key to pull:2008
# <class 'list'>
#                    State           Senator       Party  \
# 0                Alabama     Jeff Sessions  Republican
# 1                 Alaska       Ted Stevens  Republican
# 2               Arkansas        Mark Pryor  Democratic
# 3               Colorado      Wayne Allard  Republican
# 4               Delaware         Joe Biden  Democratic
# 5                Georgia   Saxby Chambliss  Republican
# 6                  Idaho       Larry Craig  Republican
# 7               Illinois       Dick Durbin  Democratic
# 8                   Iowa        Tom Harkin  Democratic
# 9                 Kansas       Pat Roberts  Republican
# 10              Kentucky   Mitch McConnell  Republican
# 11             Louisiana     Mary Landrieu  Democratic
# 12                 Maine     Susan Collins  Republican
# 13         Massachusetts        John Kerry  Democratic
# 14              Michigan        Carl Levin  Democratic
# 15             Minnesota      Norm Coleman  Republican
# 16           Mississippi      Thad Cochran  Republican
# 17               Montana        Max Baucus  Democratic
# 18              Nebraska       Chuck Hagel  Republican
# 19         New_Hampshire    John E. Sununu  Republican
# 20            New_Jersey  Frank Lautenberg  Democratic
# 21            New_Mexico     Pete Domenici  Republican
# 22        North_Carolina    Elizabeth Dole  Republican
# 23              Oklahoma        Jim Inhofe  Republican
# 24                Oregon   Gordon H. Smith  Republican
# 25          Rhode_Island         Jack Reed  Democratic
# 26        South_Carolina    Lindsey Graham  Republican
# 27          South_Dakota       Tim Johnson  Democratic
# 28             Tennessee   Lamar Alexander  Republican
# 29                 Texas       John Cornyn  Republican
# 30              Virginia       John Warner  Republican
# 31         West_Virginia   Jay Rockefeller  Democratic
# 32               Wyoming         Mike Enzi  Republican
# 33  Mississippi(Class_1)      Roger Wicker  Republican
# 34      Wyoming(Class_1)     John Barrasso  Republican
#
#                                     Electoral_History  \
# 0                                            19962002
# 1   1968 (Appointed)1970 (Special)1972197819841990...
# 2                                                2002
# 3                                            19962002
# 4                            197219781984199019962002
# 5                                                2002
# 6                                        199019962002
# 7                                            19962002
# 8                                    1984199019962002
# 9                                            19962002
# 10                                   1984199019962002
# 11                                           19962002
# 12                                           19962002
# 13                                   1984199019962002
# 14                               19781984199019962002
# 15                                               2002
# 16                               19781984199019962002
# 17                               19781984199019962002
# 18                                           19962002
# 19                                               2002
# 20     19821982 (Appointed)198819942000 (Retired)2002
# 21                           197219781984199019962002
# 22                                               2002
# 23                             1994 (Special)19962002
# 24                                           19962002
# 25                                           19962002
# 26                                               2002
# 27                                           19962002
# 28                                               2002
# 29                                               2002
# 30                               19781984199019962002
# 31                                   1984199019962002
# 32                                           19962002
# 33                                   2007 (Appointed)
# 34                                   2007 (Appointed)
#
#                                               Results  \
# 0                               Incumbent re-elected.
# 1   Incumbent lost re-election.New member elected....
# 2                               Incumbent re-elected.
# 3   Incumbent retired.New member elected.Democrati...
# 4                               Incumbent re-elected.
# 5                               Incumbent re-elected.
# 6   Incumbent retired.New member elected.Republica...
# 7                               Incumbent re-elected.
# 8                               Incumbent re-elected.
# 9                               Incumbent re-elected.
# 10                              Incumbent re-elected.
# 11                              Incumbent re-elected.
# 12                              Incumbent re-elected.
# 13                              Incumbent re-elected.
# 14                              Incumbent re-elected.
# 15  Incumbent lost re-election.New member elected....
# 16                              Incumbent re-elected.
# 17                              Incumbent re-elected.
# 18  Incumbent retired.New member elected.Republica...
# 19  Incumbent lost re-election.New member elected....
# 20                              Incumbent re-elected.
# 21  Incumbent retired.New member elected.Democrati...
# 22  Incumbent lost re-election.New member elected....
# 23                              Incumbent re-elected.
# 24  Incumbent lost re-election.New member elected....
# 25                              Incumbent re-elected.
# 26                              Incumbent re-elected.
# 27                              Incumbent re-elected.
# 28                              Incumbent re-elected.
# 29                              Incumbent re-elected.
# 30  Incumbent retired.New member elected.Democrati...
# 31                              Incumbent re-elected.
# 32                              Incumbent re-elected.
# 33                         Interim appointee elected.
# 34                         Interim appointee elected.
#
#                                            Candidates
# 0   Jeff Sessions (Republican) 63.4% Vivian Davis ...
# 1   Mark Begich (Democratic) 47.8% Ted Stevens (Re...
# 2   Mark Pryor (Democratic) 79.5% Rebekah Kennedy ...
# 3   Mark Udall (Democratic) 52.8% Bob Schaffer (Re...
# 4   Joe Biden (Democratic) 64.7% Christine O'Donne...
# 5   Saxby Chambliss (Republican) 49.8% Jim Martin ...
# 6   Jim Risch (Republican) 57.7% Larry LaRocco (De...
# 7   Dick Durbin (Democratic) 67.8% Steve Sauerberg...
# 8   Tom Harkin (Democratic) 62.7% Christopher Reed...
# 9   Pat Roberts (Republican) 60.0%Jim Slattery (De...
# 10  Mitch McConnell (Republican) 53.0% Bruce Lunsf...
# 11  Mary Landrieu (Democratic) 52.1% John Kennedy ...
# 12  Susan Collins (Republican) 61.3% Tom Allen (De...
# 13  John Kerry (Democratic) 65.8% Jeff Beatty (Rep...
# 14  Carl Levin (Democratic) 62.7% Jack Hoogendyk (...
# 15  Al Franken (DFL) 41.99% Norm Coleman (Republic...
# 16  Thad Cochran (Republican) 61.4% Erik Fleming (...
# 17  Max Baucus (Democratic) 72.9% Bob Kelleher (Re...
# 18  Mike Johanns (Republican) 57.5% Scott Kleeb (D...
# 19  Jeanne Shaheen (Democratic) 51.7% John E. Sunu...
# 20  Frank Lautenberg (Democratic) 56.0% Dick Zimme...
# 21  Tom Udall (Democratic) 61.3% Steve Pearce (Rep...
# 22  Kay Hagan (Democratic) 52.7% Elizabeth Dole (R...
# 23  Jim Inhofe (Republican) 56.7% Andrew Rice (Dem...
# 24  Jeff Merkley (Democratic) 48.9% Gordon H. Smit...
# 25  Jack Reed (Democratic) 73.4% Robert Tingle (Re...
# 26  Lindsey Graham (Republican) 57.5% Bob Conley (...
# 27  Tim Johnson (Democratic) 62.5% Joel Dykstra (R...
# 28  Lamar Alexander (Republican) 65.1% Bob Tuke (D...
# 29  John Cornyn (Republican) 54.8% Rick Noriega (D...
# 30  Mark Warner (Democratic) 65.0% Jim Gilmore (Re...
# 31  Jay Rockefeller (Democratic) 63.7% Jay Wolfe (...
# 32  Mike Enzi (Republican) 75.6% Chris Rothfuss (D...
# 33  Roger Wicker (Republican) 55.0% Ronnie Musgrov...
# 34  John Barrasso (Republican) 73.4% Nick Carter (...
#                 State_id         Incumbent  Year
# 0                Alabama     Jeff Sessions  2008
# 1                 Alaska       Ted Stevens  2008
# 2               Arkansas        Mark Pryor  2008
# 3               Colorado      Wayne Allard  2008
# 4               Delaware         Joe Biden  2008
# 5                Georgia   Saxby Chambliss  2008
# 6                  Idaho       Larry Craig  2008
# 7               Illinois       Dick Durbin  2008
# 8                   Iowa        Tom Harkin  2008
# 9                 Kansas       Pat Roberts  2008
# 10              Kentucky   Mitch McConnell  2008
# 11             Louisiana     Mary Landrieu  2008
# 12                 Maine     Susan Collins  2008
# 13         Massachusetts        John Kerry  2008
# 14              Michigan        Carl Levin  2008
# 15             Minnesota      Norm Coleman  2008
# 16           Mississippi      Thad Cochran  2008
# 17               Montana        Max Baucus  2008
# 18              Nebraska       Chuck Hagel  2008
# 19         New_Hampshire    John E. Sununu  2008
# 20            New_Jersey  Frank Lautenberg  2008
# 21            New_Mexico     Pete Domenici  2008
# 22        North_Carolina    Elizabeth Dole  2008
# 23              Oklahoma        Jim Inhofe  2008
# 24                Oregon   Gordon H. Smith  2008
# 25          Rhode_Island         Jack Reed  2008
# 26        South_Carolina    Lindsey Graham  2008
# 27          South_Dakota       Tim Johnson  2008
# 28             Tennessee   Lamar Alexander  2008
# 29                 Texas       John Cornyn  2008
# 30              Virginia       John Warner  2008
# 31         West_Virginia   Jay Rockefeller  2008
# 32               Wyoming         Mike Enzi  2008
# 33  Mississippi(Class_1)      Roger Wicker  2008
# 34      Wyoming(Class_1)     John Barrasso  2008

# %%
test3 = dlf.table_checker(dict_=yr_st_dict_mapped)
print(type(test3))
test3
# Out:
# Key to pull:2008
# <class 'pandas.core.frame.DataFrame'>
#                     Party                    Candidate       %  Turnout  \
# 0              Republican    Jeff Sessions (Incumbent)  63.36%      NaN
# 1              Democratic               Vivian Figures  36.52%      NaN
# 2                Write-in                    Write-ins   0.12%      NaN
# 3              Democratic                  Mark Begich  84.12%      NaN
# 4              Democratic                 Ray Metcalfe   7.23%      NaN
# 5    Alaskan Independence                     Bob Bird   5.56%      NaN
# 6             Libertarian               Fredrick Haase   1.81%      NaN
# 7              Democratic             Frank Vondersaar   1.27%      NaN
# 8              Democratic                  Mark Begich  47.77%   317723
# 9              Republican      Ted Stevens (Incumbent)  46.52%   317723
# 10   Alaskan Independence                     Bob Bird   4.15%   317723
# 11            Libertarian               Fredrick Haase   0.78%   317723
# 12             Democratic       Mark Pryor (Incumbent)  79.53%      NaN
# 13                  Green              Rebekah Kennedy  20.47%      NaN
# 14             Democratic                   Mark Udall  52.80%  2331621
# 15             Republican                 Bob Schaffer  42.49%  2331621
# 16           Constitution             Douglas Campbell   2.56%  2331621
# 17             Democratic        Joe Biden (Incumbent)  64.69%   398134
# 18             Republican          Christine O'Donnell  35.31%   398134
# 19             Republican  Saxby Chambliss (Incumbent)   49.8%  3752577
# 20             Democratic                   Jim Martin   46.8%  3752577
# 21            Libertarian                Allen Buckley    3.4%  3752577
# 22             Republican  Saxby Chambliss (Incumbent)   57.4%  2137956
# 23             Democratic                   Jim Martin   42.6%  2137956
# 24             Republican                    Jim Risch  57.65%   644780
# 25             Democratic                Larry LaRocco  34.11%   644780
# 26            Libertarian                  Kent Marmon   1.54%   644780
# 27             Democratic      Dick Durbin (Incumbent)  67.84%  5329884
# 28             Republican              Steve Sauerberg  28.53%  5329884
# 29                  Green               Kathy Cummings   2.24%  5329884
# ..                    ...                          ...     ...      ...
# 78             Democratic                    Kay Hagan  52.65%  4271970
# 79             Republican   Elizabeth Dole (Incumbent)  44.18%  4271970
# 80            Libertarian                   Chris Cole   3.17%  4271970
# 81                  Other                    Write-Ins    0.0%  4271970
# 82             Republican       Jim Inhofe (Incumbent)  56.68%  1346819
# 83             Democratic                  Andrew Rice  39.18%  1346819
# 84             Democratic                 Jeff Merkley  48.90%  1767504
# 85             Republican  Gordon H. Smith (Incumbent)  45.55%  1767504
# 86           Constitution               David Brownlow   5.24%  1767504
# 87             Democratic                    Jack Reed   73.4%   436818
# 88             Republican                   Bob Tingle   26.6%   436818
# 89             Republican               Lindsey Graham  57.52%  1871431
# 90             Democratic                   Bob Conley  42.25%  1871431
# 91             Democratic      Tim Johnson (Incumbent)  62.49%   380673
# 92             Republican                 Joel Dykstra  37.51%   380673
# 93             Republican  Lamar Alexander (Incumbent)  65.14%  2424585
# 94             Democratic                     Bob Tuke  31.64%  2424585
# 95             Republican                  John Cornyn  54.82%  7912075
# 96             Democratic                 Rick Noriega  42.83%  7912075
# 97            Libertarian          Yvonne Adams Schick   2.34%  7912075
# 98             Democratic                  Mark Warner  65.03%  3643294
# 99             Republican                  Jim Gilmore  33.72%  3643294
# 100    Independent Greens                Glenda Parker   0.60%  3643294
# 101           Libertarian                 Bill Redpath   0.56%  3643294
# 102            Democratic  Jay Rockefeller (Incumbent)   63.7%   702189
# 103            Republican                    Jay Wolfe   36.3%   702189
# 104            Republican                    Mike Enzi  75.63%   249946
# 105            Democratic               Chris Rothfuss  24.26%   249946
# 106            Republican                John Barrasso  73.35%   249558
# 107            Democratic                  Nick Carter  26.53%   249558
#
#      Incumb_Y           State
# 0           1         Alabama
# 1           0            None
# 2           0            None
# 3           0          Alaska
# 4           0            None
# 5           0            None
# 6           0            None
# 7           0            None
# 8           0          Alaska
# 9           1          Alaska
# 10          0            None
# 11          0            None
# 12          1        Arkansas
# 13          0            None
# 14          0        Colorado
# 15          0            None
# 16          0            None
# 17          1        Delaware
# 18          0            None
# 19          1         Georgia
# 20          0            None
# 21          0            None
# 22          1         Georgia
# 23          0            None
# 24          0           Idaho
# 25          0            None
# 26          0            None
# 27          1        Illinois
# 28          0            None
# 29          0            None
# ..        ...             ...
# 78          0  North_Carolina
# 79          1  North_Carolina
# 80          0            None
# 81          0            None
# 82          1        Oklahoma
# 83          0            None
# 84          0          Oregon
# 85          1          Oregon
# 86          0            None
# 87          0    Rhode_Island
# 88          0            None
# 89          0  South_Carolina
# 90          0            None
# 91          1    South_Dakota
# 92          0            None
# 93          1       Tennessee
# 94          0            None
# 95          0           Texas
# 96          0            None
# 97          0            None
# 98          0        Virginia
# 99          0            None
# 100         0            None
# 101         0            None
# 102         1   West_Virginia
# 103         0            None
# 104         0         Wyoming
# 105         0            None
# 106         0         Wyoming
# 107         0            None
#
# [108 rows x 6 columns]

# %%
display(ldr_master_df.head(15))
# Out:
#                                      Leader   Leaders_seat     Leader_since  \
# 0                           Mitch McConnell       Kentucky  January 3, 2007
# 1                             Chuck Schumer       New York  January 3, 2017
# 2                                       NaN            NaN              NaN
# 3                           John W. Kern[a]        Indiana              NaN
# 4                     Jacob H. Gallinger[a]  New Hampshire              NaN
# 5                                       NaN            NaN              NaN
# 6         John W. Kern(Conference Chairman)        Indiana              NaN
# 7   Jacob H. Gallinger(Conference Chairman)  New Hampshire              NaN
# 8             Henry Cabot Lodge(unofficial)  Massachusetts    March 4, 1919
# 9                           Oscar Underwood        Alabama   April 27, 1920
# 10            Henry Cabot Lodge(unofficial)  Massachusetts    March 4, 1919
# 11                          Oscar Underwood        Alabama   April 27, 1920
# 12            Henry Cabot Lodge(unofficial)  Massachusetts    March 4, 1919
# 13                          Oscar Underwood        Alabama   April 27, 1920
# 14                                      NaN            NaN              NaN
#
#            Party Percentage      Popular_vote Races_won Seats_up Seats_won  \
# 0     Republican     38.80%     34,723,013[a]        11        9       NaN
# 1     Democratic  58.40%[c]  52,260,651[b][c]        22       24       NaN
# 2    Independent      1.00%        892,988[d]         2        2       NaN
# 3     Democratic        NaN               NaN       NaN       16        19
# 4     Republican        NaN               NaN       NaN       18        15
# 5    Progressive        NaN               NaN       NaN        0         0
# 6     Democratic        NaN               NaN       NaN       17     16[a]
# 7     Republican        NaN               NaN       NaN       15     16[a]
# 8     Republican        NaN               NaN       NaN       17        23
# 9     Democratic        NaN               NaN       NaN       24        18
# 10    Republican        NaN               NaN        25       15       NaN
# 11    Democratic        NaN               NaN         7       17       NaN
# 12    Republican        NaN               NaN        10       17       NaN
# 13    Democratic        NaN               NaN        21       15       NaN
# 14  Farmer–Labor        NaN               NaN         1      NaN       NaN
#
#    Seats_after Seats_before Seat_change  Swing  Year
# 0           53           51           2  3.60%  2018
# 1           45           47           2  4.50%  2018
# 2            2            2         NaN  0.50%  2018
# 3           53           50           3    NaN  1914
# 4           41           44           3    NaN  1914
# 5            1            1         NaN    NaN  1914
# 6        55[a]           56        1[a]    NaN  1916
# 7        41[a]           40        1[a]    NaN  1916
# 8           49           43           6    NaN  1918
# 9           47           53           6    NaN  1918
# 10          59           49          10    NaN  1920
# 11          37           47          10    NaN  1920
# 12          53           60           7    NaN  1922
# 13          42           36           6    NaN  1922
# 14           1            0           1    NaN  1922

# %%
ldr_master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 14 columns):
# Leader          106 non-null object
# Leaders_seat    106 non-null object
# Leader_since    94 non-null object
# Party           148 non-null object
# Percentage      100 non-null object
# Popular_vote    102 non-null object
# Races_won       135 non-null object
# Seats_up        147 non-null object
# Seats_won       34 non-null object
# Seats_after     127 non-null object
# Seats_before    148 non-null object
# Seat_change     107 non-null object
# Swing           90 non-null object
# Year            148 non-null object
# dtypes: object(14)
# memory usage: 16.3+ KB

# %% [markdown]
# ************************************
# Columns:
# * Leader: All `NaN`s are in non-traditional parties. **Fill with '3rd_Party'.**
# * Leader's seat: ***SEE ABOVE***
# * Leader since:
#     * Index [3,4] are first time leaders (1914); [6,7] are the same people (1916)
#     * `'Harry Reid'`, Index [133, 136, 139, 146] is since 1/3/2005.
#     * `'Mitch McConell'`, Index [134, 137, 140, 145] is since 1/3/2007.
#     * All other `NaN`s are '3rd_party'.
# * **Party: G2G!!**
# * **Percentage: N/A or DROP**
# * **Popular vote: N/A or DROP**
# * **Races won: N/A or DROP**
# * Seats up: '3rd_party' candidate at Index [14] is 0
# * **Seats won: N/A or DROP**
# * **Seats after: N/A or DROP**
# * **Seats before: G2G!!**
# * **Seats change: N/A or DROP**
# * **Swing: N/A or DROP**
# * **Year: G2G!!**

# %%
ldr_master_df.columns
# Out:
# Index(['Leader', 'Leaders_seat', 'Leader_since', 'Party', 'Percentage',
#        'Popular_vote', 'Races_won', 'Seats_up', 'Seats_won', 'Seats_after',
#        'Seats_before', 'Seat_change', 'Swing', 'Year'],
#       dtype='object')

# %%
ldr_master_df[ldr_master_df['Seats_after'].isna()]
# Out:
#                     Leader   Leaders_seat       Leader_since         Party  \
# 42           Alben Barkley       Kentucky      July 22, 1937    Democratic
# 43          Charles McNary         Oregon    January 3, 1941    Republican
# 44                     NaN            NaN                NaN  Farmer–Labor
# 45                     NaN            NaN                NaN   Progressive
# 46           Alben Barkley       Kentucky      July 22, 1937    Democratic
# 47           Wallace White          Maine  February 25, 1944    Republican
# 48                     NaN            NaN                NaN   Progressive
# 49                     NaN            NaN                NaN   Independent
# 50           Alben Barkley       Kentucky      July 22, 1937    Democratic
# 51           Wallace White          Maine  February 25, 1944    Republican
# 52                     NaN            NaN                NaN   Progressive
# 53           Wallace White          Maine  February 25, 1944    Republican
# 54           Alben Barkley       Kentucky      July 22, 1937    Democratic
# 55                     NaN            NaN                NaN   Progressive
# 62          Lyndon Johnson          Texas    January 3, 1953    Democratic
# 63           Bill Knowland     California     August 4, 1953    Republican
# 64                     NaN            NaN                NaN   Independent
# 104  Howard Baker(retired)      Tennessee      March 5, 1980    Republican
# 105            Robert Byrd  West Virginia    January 3, 1977    Democratic
# 116             Trent Lott    Mississippi      June 12, 1996    Republican
# 117            Tom Daschle   South Dakota    January 3, 1995    Democratic
#
#     Percentage Popular_vote Races_won Seats_up Seats_won Seats_after  \
# 42       47.5%     19715831        21       23        66         NaN
# 43       47.8%     19831926        10        7        27         NaN
# 44    25.7%[1]   310,875[1]         0        1         0         NaN
# 45        1.5%       605609         1        1         1         NaN
# 46       46.7%      6329426        15       23        57         NaN
# 47       49.2%      6661196        17        9        38         NaN
# 48         [?]          [?]         0        0         1         NaN
# 49         [?]          [?]         0        1         0         NaN
# 50       50.3%     17590770        21       21        58         NaN
# 51       46.1%     16127651        11       11        37         NaN
# 52        0.2%        73089         0        0         1         NaN
# 53       54.5%     14984498        21       10        50         NaN
# 54       41.4%     11369078        11       21        46         NaN
# 55         NaN          NaN         0        1         0         NaN
# 62       55.5%     11402106        22       20        48         NaN
# 63       43.0%      8839779        10       12        47         NaN
# 64         NaN          NaN         0        0         1         NaN
# 104      49.3%     22850493        17       19        53         NaN
# 105      49.8%     23079278        16       14        47         NaN
# 116      49.4%     24211395        20       18        55         NaN
# 117      47.9%     23490651        13       15        45         NaN
#
#     Seats_before Seat_change  Swing  Year
# 42            69           2    NaN  1940
# 43            24           3    NaN  1940
# 44             1           1    NaN  1940
# 45             1         NaN    NaN  1940
# 46            65           8   0.8%  1942
# 47            29           9   1.4%  1942
# 48             1         NaN    NaN  1942
# 49             1           1    NaN  1942
# 50            58         NaN   3.6%  1944
# 51            37         NaN   3.1%  1944
# 52             1         NaN   0.2%  1944
# 53            39          11   8.4%  1946
# 54            56          10   8.9%  1946
# 55             1           1    NaN  1946
# 62            46           2  10.8%  1954
# 63            49           2   8.9%  1954
# 64             1         NaN    NaN  1954
# 104           55           2   5.9%  1984
# 105           45           2   4.3%  1984
# 116           53           2   0.5%  1996
# 117           47           2   3.9%  1996

# %%
display(name_lookup_df.head(15))
# Out:
#        State_id               Incumbent  Year  Terms_in_office
# 0       Alabama        Francis S. White  1914                1
# 1       Arizona         Marcus A. Smith  1914                1
# 2      Arkansas       James Paul Clarke  1914                1
# 3    California  George Clement Perkins  1914                1
# 4      Colorado       Charles S. Thomas  1914                1
# 5   Connecticut      Frank B. Brandegee  1914                1
# 6       Florida      Duncan U. Fletcher  1914                1
# 7       Georgia           M. Hoke Smith  1914                1
# 8         Idaho          James H. Brady  1914                1
# 9      Illinois     Lawrence Y. Sherman  1914                1
# 10      Indiana     Benjamin F. Shively  1914                1
# 11         Iowa       Albert B. Cummins  1914                1
# 12       Kansas       Joseph L. Bristow  1914                1
# 13     Kentucky   Johnson N. Camden Jr.  1914                1
# 14    Louisiana           John Thornton  1914                1

# %% [markdown]
# combine yearly tables, add state/year column

# %% [markdown]
# **8.9 Need to try and merge `yr_st_dict_mapped`, `ldr_master_df` and use parts of `name_lookup_df`**

# %%
election_collection_raw['1976'][0]
# Out:
#                 0                        1                    2
# 0             NaN                      NaN                  NaN
# 1          Leader  Mike Mansfield(retired)  Hugh Scott(retired)
# 2           Party               Democratic           Republican
# 3    Leader since          January 3, 1961   September 24, 1969
# 4   Leader's seat                  Montana         Pennsylvania
# 5    Seats before                       61                   37
# 6     Seats after                       61                   38
# 7     Seat change                      NaN                    1
# 8    Popular vote                 31790526             24562431
# 9      Percentage                    53.7%                41.5%
# 10          Swing                     1.5%                 1.9%
# 11       Seats up                       21                   10
# 12      Races won                       21                   11
# 13            NaN                      NaN                  NaN
# 14            NaN                      NaN                  NaN
# 15          Party              Independent         Conservative
# 16   Seats before                        1                    1
# 17    Seats after                     1[a]                    0
# 18    Seat change                      NaN                    1
# 19   Popular vote                   890778               311494
# 20       Seats up                        1                    1
# 21      Races won                        1                    0

# %%
# test1 = dlf.table_checker(dict_=sen_leader_dict)
# print(type(test1))
# test1

# %%
# test = dlf.table_checker(dict_=sen_leader_dict)
# print(type(test))
# test
